# %%
import urllib2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-846c1dbd158b> in <module>()
# ----> 1 import urllib2
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
import requests

# %%
web_add = 'https://www.nass.usda.gov/Data_and_Statistics/County_Data_Files/Frequently_Asked_Questions/county_list.txt'
response = requests.get(web_add)
data = response.text
data
# Out:
# "Listing of Counties and Districts used by USDA-NASS, updated 08-15-2007\r\n\r\n     D                              \r\n     i                              \r\nS    s    C                            History \r\nt    t    o     State                   flag\r\na    r    u       or                1 = currently being used\r\nt    i    n     County              2 = historical \r\ne    c    t      Name               \r\n     t    y                         \r\n\r\n\r\n01   00   000   Alabama\t\t\t\t\t\t1\r\n01   10   033   Colbert\t\t\t\t\t\t1\r\n01   10   057   Fayette\t\t\t\t\t\t2\r\n01   10   059   Franklin\t\t\t\t\t1\r\n01   10   075   Lamar\t\t\t\t\t\t2\r\n01   10   077   Lauderdale\t\t\t\t\t1\r\n01   10   079   Lawrence\t\t\t\t\t1\r\n01   10   083   Limestone\t\t\t\t\t1\r\n01   10   089   Madison\t\t\t\t\t\t1\r\n01   10   093   Marion\t\t\t\t\t\t1\r\n01   10   103   Morgan\t\t\t\t\t\t1\r\n01   10   133   Winston\t\t\t\t\t\t1\r\n01   10   888   D10 Combined Counties\t\t\t\t1\r\n01   10
# ...

# %%
# Out:
# "Listing of Counties and Districts used by USDA-NASS, updated 08-15-2007\r\n\r\n     D                              \r\n     i                              \r\nS    s    C                            History \r\nt    t    o     State                   flag\r\na    r    u       or                1 = currently being used\r\nt    i    n     County              2 = historical \r\ne    c    t      Name               \r\n     t    y                         \r\n\r\n\r\n01   00   000   Alabama\t\t\t\t\t\t1\r\n01   10   033   Colbert\t\t\t\t\t\t1\r\n01   10   057   Fayette\t\t\t\t\t\t2\r\n01   10   059   Franklin\t\t\t\t\t1\r\n01   10   075   Lamar\t\t\t\t\t\t2\r\n01   10   077   Lauderdale\t\t\t\t\t1\r\n01   10   079   Lawrence\t\t\t\t\t1\r\n01   10   083   Limestone\t\t\t\t\t1\r\n01   10   089   Madison\t\t\t\t\t\t1\r\n01   10   093   Marion\t\t\t\t\t\t1\r\n01   10   103   Morgan\t\t\t\t\t\t1\r\n01   10   133   Winston\t\t\t\t\t\t1\r\n01   10   888   D10 Combined Counties\t\t\t\t1\r\n01   10
# ...

# %%
import urllib3

# %%
http = urllib3.PoolManager()

# %%
response_1 = http.request('GET', web_add)
# Out:
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
data = response_1.data.decode('utf-8')

# %%
data
# Out:
# "Listing of Counties and Districts used by USDA-NASS, updated 08-15-2007\r\n\r\n     D                              \r\n     i                              \r\nS    s    C                            History \r\nt    t    o     State                   flag\r\na    r    u       or                1 = currently being used\r\nt    i    n     County              2 = historical \r\ne    c    t      Name               \r\n     t    y                         \r\n\r\n\r\n01   00   000   Alabama\t\t\t\t\t\t1\r\n01   10   033   Colbert\t\t\t\t\t\t1\r\n01   10   057   Fayette\t\t\t\t\t\t2\r\n01   10   059   Franklin\t\t\t\t\t1\r\n01   10   075   Lamar\t\t\t\t\t\t2\r\n01   10   077   Lauderdale\t\t\t\t\t1\r\n01   10   079   Lawrence\t\t\t\t\t1\r\n01   10   083   Limestone\t\t\t\t\t1\r\n01   10   089   Madison\t\t\t\t\t\t1\r\n01   10   093   Marion\t\t\t\t\t\t1\r\n01   10   103   Morgan\t\t\t\t\t\t1\r\n01   10   133   Winston\t\t\t\t\t\t1\r\n01   10   888   D10 Combined Counties\t\t\t\t1\r\n01   10
# ...

# %%
from urllib.request import urlopen
data_1 = urlopen(web_add)
data_1

# %%
import csv
from urllib.request import urlopen
html = urlopen(web_add)

# %%
cr = csv.reader(data)
for row in cr:
    print (row)
# Out:
# ['L']
# ['i']
# ['s']
# ['t']
# ['i']
# ['n']
# ['g']
# [' ']
# ['o']
# ['f']
# [' ']
# ['C']
# ['o']
# ['u']
# ['n']
# ['t']
# ['i']
# ['e']
# ['s']
# [' ']
# ['a']
# ['n']
# ['d']
# [' ']
# ['D']
# ['i']
# ['s']
# ['t']
# ['r']
# ['i']
# ['c']
# ['t']
# ['s']
# [' ']
# ['u']
# ['s']
# ['e']
# ['d']
# [' ']
# ['b']
# ['y']
# [' ']
# ['U']
# ['S']
# ['D']
# ['A']
# ['-']
# ['N']
# ['A']
# ['S']
# ['S']
# ['', '']
# [' ']
# ['u']
# ['p']
# ['d']
# ['a']
# ['t']
# ['e']
# ['d']
# [' ']
# ['0']
# ['8']
# ['-']
# ['1']
# ['5']
# ['-']
# ['2']
# ['0']
# ['0']
# ['7']
# []
# []
# []
# []
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# ['D']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# []
# []
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# ['i']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# [' ']
# ...

# %%
import urllib
txt = urllib.request.urlopen(web_add).read()

# %%
csv_file = r"mycsv.csv"

# %%
out_csv = csv.writer(open(csv_file, 'wb'))

# %%
out_csv

# %%
out_csv.writerows(txt)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-85-a984c872ed58> in <module>()
# ----> 1 out_csv.writerows(txt)
#
# Error: iterable expected, not int

# %%
with open('/Users/hn/Documents/GitHub/Kirti/merge_irrigation_Monday/NASS_counties.txt', 'r') as in_file:
    stripped = (line.strip() for line in in_file)
    lines = (line.split(",") for line in stripped if line)
    with open('log.csv', 'w') as out_file:
        writer = csv.writer(out_file)
        writer.writerow(('title', 'intro'))
        writer.writerows(lines)

# %%
lines
# Out:
# <generator object <genexpr> at 0x10feaafc0>
