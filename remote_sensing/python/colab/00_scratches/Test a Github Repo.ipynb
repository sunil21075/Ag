# %% [markdown]
# # Test a Github Repo

# %%
# !earthengine authenticate
# Out:
# Running command using Cloud API.  Set --no-use_cloud_api to go back to using the API
#
# /usr/local/lib/python3.6/dist-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/vgFK5vq7Yp-g4MNt3fGADgcKATYmQC7h1POAQs2ZRBlhjrOEOMjYYyw
#
# Successfully saved authorization token.

# %%
import ee
ee.Initialize()

# %%
# !pip install geetools
# !pip install geebap
# Out:
# Requirement already satisfied: geetools in /usr/local/lib/python3.6/dist-packages (0.4.13)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from geetools) (6.2.2)
# Requirement already satisfied: pyshp in /usr/local/lib/python3.6/dist-packages (from geetools) (2.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from geetools) (0.25.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from geetools) (2.21.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->geetools) (2.6.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas->geetools) (1.17.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->geetools) (2018.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->geetools) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->geetools) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->geetools) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->geetools) (2019.11.28)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas->geetools) (1.12.0)
# Collecting geebap
#   Downloading https://files.pythonhosted.org/packages/dd/c3/356f2520f5a813349c38c70e74c3b54872e27c24be1307b04b4388e63c6c/geebap-0.2.5.tar.gz (46kB)
#      |████████████████████████████████| 51kB 1.7MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from geebap) (2.21.0)
# Collecting simpleeval
#   Downloading https://files.pythonhosted.org/packages/62/25/aec98426834844b70b7ab24b4cce8655d31e654f58e1fa9861533f5f2af1/simpleeval-0.9.10.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from geebap) (1.17.5)
# Requirement already satisfied: geetools>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from geebap) (0.4.13)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->geebap) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->geebap) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->geebap) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->geebap) (2.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from geetools>=0.2.2->geebap) (0.25.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from geetools>=0.2.2->geebap) (6.2.2)
# Requirement already satisfied: pyshp in /usr/local/lib/python3.6/dist-packages (from geetools>=0.2.2->geebap) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->geetools>=0.2.2->geebap) (2.6.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->geetools>=0.2.2->geebap) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas->geetools>=0.2.2->geebap) (1.12.0)
# Building wheels for collected packages: geebap, simpleeval
#   Building wheel for geebap (setup.py) ... done
#   Created wheel for geebap: filename=geebap-0.2.5-cp36-none-any.whl size=50433 sha256=d32730af6f1e664dff2af3b97a535d7f4d54399191713ee1da88f45d05b4c939
#   Stored in directory: /root/.cache/pip/wheels/60/ab/25/8865b36541224338cbc0e7f6e19cbf437b5d84aacfd572083d
#   Building wheel for simpleeval (setup.py) ... done
#   Created wheel for simpleeval: filename=simpleeval-0.9.10-cp36-none-any.whl size=13758 sha256=f882759ad897516fb15d70783e0fb31e7f741b45bd82b0dfcb3d630dfe3169b8
#   Stored in directory: /root/.cache/pip/wheels/20/ab/91/eeb7746161f88e6ea897483494ab6034ebce9884b8f2dea7e5
# Successfully built geebap simpleeval
# Installing collected packages: simpleeval, geebap
# Successfully installed geebap-0.2.5 simpleeval-0.9.10

# %%
from geetools import ui, tools, collection
from geebap import scores
from geebap.season import Season

# %%
p = ee.Geometry.Point([-71.33972167968751, -42.737619925503054])
aoi = p.buffer(8000).bounds()

# %%
col = collection.Landsat8SR()
colEE = col.collection.filterBounds(aoi)
year = 2018
start = '11-15'
end = '02-15'

# %%
season = Season(start, end)
date_range = season.add_year(year)
colEE = colEE.filterDate(date_range.start(), date_range.end())
doy = '12-15'

# %%
score = scores.Doy(season=season, best_doy=doy, function='linear')
newcol = score.map(colEE, year=year)
chart = ui.chart.Image.series(newcol, p, scale=30, bands=[score.name], label_bands=['linear'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-447470c555f6> in <module>()
#       1 score = scores.Doy(season=season, best_doy=doy, function='linear')
#       2 newcol = score.map(colEE, year=year)
# ----> 3 chart = ui.chart.Image.series(newcol, p, scale=30, bands=[score.name], label_bands=['linear'])
#
# AttributeError: module 'geetools.ui' has no attribute 'chart'
